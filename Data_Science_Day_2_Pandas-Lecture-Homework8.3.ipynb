# %% [markdown]
# # Data Science Pandas

# %% [markdown]
# ## Tasks Today:
# 1) <b>Pandas</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Tabular Data Structures <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - from_dict() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - read_csv() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Accessing Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Indexing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.loc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - keys() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Slicing a DataFrame <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Built-In Methods <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - head() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - tail() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - shape <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - describe() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - sort_values() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - .columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Filtration <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Conditionals <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subsetting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Column Transformations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Generating a New Column w/Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - User Defined Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Aggregations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Type of groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - mean() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() w/Multiple Columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - drop_duplicates() <br>

# %% [markdown]
# ## Pandas <br>
#
# <p>Pandas is a flexible data analysis library built on top of NumPy that is excellent for working with tabular data. It is currently the de-facto standard for Python-based data analysis, and fluency in Pandas will do wonders for your productivity and frankly your resume. It is one of the fastest ways of getting from zero to answer in existence. </p>
#
# <ul>
#     <li>Pandas is a Python module, written in C. The Pandas module is a high performance, highly efficient, and high level data analysis library. It allows us to work with large sets of data called dataframes.</li>
#     <li>Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)</li>
#     <li>Dataframe = Spreadsheet (has column headers, index, etc.)</li>
# </ul>

# %% [markdown]
# ### Importing

# %%
import numpy as np
# always use pd, standard for data science

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\todds\\anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %% [markdown]
# ### Tabular data structures <br>
# <p>The central object of study in Pandas is the DataFrame, which is a tabular data structure with rows and columns like an excel spreadsheet. The first point of discussion is the creation of dataframes both from native Python dictionaries, and text files through the Pandas I/O system.</p>

# %%
names = ['Alice',
         'Bob',
         'James',
         'Beth', 
         'John', 
         'Sally',
         'Richard', 
         'Lauren',
         'Brandon', 
         'Sabrina']

ages = np.random.randint(18,35,len(names))

my_people = {
    'names': names,
    'ages': ages
}

my_people
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# {'names': ['Alice',
#   'Bob',
#   'James',
#   'Beth',
#   'John',
#   'Sally',
#   'Richard',
#   'Lauren',
#   'Brandon',
#   'Sabrina'],
#  'ages': array([21, 18, 27, 28, 28, 26, 20, 19, 24, 19])}

# %% [markdown]
# ##### from_dict()
#
# <p>Let's convert our not-so-useful-for-analysis dict into a Pandas dataframe. We can use the from_dict function to do this easily using Pandas:</p>

# %%
import pandas as pd

# %%
data = pd.DataFrame.from_dict(my_people)

data
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
#      names  ages
# 0    Alice    21
# 1      Bob    18
# 2    James    27
# 3     Beth    28
# 4     John    28
# 5    Sally    26
# 6  Richard    20
# 7   Lauren    19
# 8  Brandon    24
# 9  Sabrina    19

# %% [markdown]
# ##### read_csv()

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# read_csv() takes 2 parameters
# filename
# separator aka what character is separating the columns within the file

marathon = pd.read_csv('files/boston_marathon2017_edited.csv', sep=',')
marathon
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:223: RuntimeWarning: divide by zero encountered in equal
#   chunks = self._reader.read_low_memory(nrows)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:679: RuntimeWarning: divide by zero encountered in isnan
#   checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:679: RuntimeWarning: divide by zero encountered in isnan
#   checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
#                           10K                     15K                    20K  \
# 0      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 1      12/30/1899 12:30:27 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 2      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:16 AM
# 3      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:19 AM
# 4      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# ...                       ...                     ...                    ...
# 26405   12/30/1899 1:35:41 AM   12/30/1899 2:23:35 AM  12/30/1899 3:12:44 AM
# 26406   12/30/1899 1:05:33 AM   12/30/1899 1:52:17 AM  12/30/1899 2:49:41 AM
# 26407   12/30/1899 1:43:36 AM   12/30/1899 2:32:36 AM                    NaN
# 26408   12/30/1899 1:27:19 AM   12/30/1899 2:17:17 AM  12/30/1899 3:11:40 AM
# 26409   12/30/1899 1:17:12 AM   12/30/1899 2:00:10 AM  12/30/1899 2:58:55 AM
#
#                          25K                    30K                    35K  \
# 0      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 1      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 2      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:31 AM
# 3      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:58 AM
# 4      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:41 AM
# ...                      ...                    ...                    ...
# 26405  12/30/1899 4:12:06 AM  12/30/1899 5:03:08 AM  12/30/1899 5:55:18 AM
# 26406  12/30/1899 3:50:19 AM  12/30/1899 4:50:01 AM  12/30/1899 5:53:48 AM
# 26407  12/30/1899 4:15:21 AM  12/30/1899 5:06:37 AM  12/30/1899 6:00:33 AM
# 26408  12/30/1899 4:06:10 AM  12/30/1899 5:07:09 AM  12/30/1899 6:06:07 AM
# 26409  12/30/1899 4:27:14 AM  12/30/1899 5:37:13 AM  12/30/1899 6:39:07 AM
#
#                          40K                      5K  Age      Bib  ...  \
# 0      12/30/1899 2:02:53 AM  12/30/1899 12:15:25 AM   24     11.0  ...
# 1      12/30/1899 2:03:14 AM  12/30/1899 12:15:24 AM   30     17.0  ...
# 2      12/30/1899 2:03:38 AM  12/30/1899 12:15:25 AM   25     23.0  ...
# 3      12/30/1899 2:04:35 AM  12/30/1899 12:15:25 AM   32     21.0  ...
# 4      12/30/1899 2:05:00 AM  12/30/1899 12:15:25 AM   31      9.0  ...
# ...                      ...                     ...  ...      ...  ...
# 26405  12/30/1899 6:46:57 AM  12/30/1899 12:46:44 AM   61  25166.0  ...
# 26406  12/30/1899 6:54:21 AM  12/30/1899 12:32:03 AM   25  25178.0  ...
# 26407  12/30/1899 6:54:38 AM  12/30/1899 12:53:11 AM   57  27086.0  ...
# 26408  12/30/1899 6:56:08 AM  12/30/1899 12:40:34 AM   64  25268.0  ...
# 26409  12/30/1899 7:41:23 AM  12/30/1899 12:39:36 AM   48  25266.0  ...
#
#        Division Gender                   Half  M/F                      Name  \
# 0             1      1  12/30/1899 1:04:35 AM    M           Kirui, Geoffrey
# 1             2      2  12/30/1899 1:04:35 AM    M               Rupp, Galen
# 2             3      3  12/30/1899 1:04:36 AM    M             Osako, Suguru
# 3             4      4  12/30/1899 1:04:45 AM    M          Biwott, Shadrack
# 4             5      5  12/30/1899 1:04:35 AM    M            Chebet, Wilson
# ...         ...    ...                    ...  ...                       ...
# 26405       344  11972  12/30/1899 3:23:31 AM    F  Steinbach, Paula Eyvonne
# 26406      4774  14436  12/30/1899 3:00:26 AM    M        Avelino, Andrew R.
# 26407       698  11973  12/30/1899 3:36:24 AM    F           Hantel, Johanna
# 26408      1043  14437  12/30/1899 3:22:30 AM    M              Reilly, Bill
# 26409      2553  14438  12/30/1899 3:08:16 AM    M             Rigsby, Scott
#
#       Number of Records          Official Time  Overall  \
# 0                     1  12/30/1899 2:09:37 AM        1
# 1                     1  12/30/1899 2:09:58 AM        2
# 2                     1  12/30/1899 2:10:28 AM        3
# 3                     1  12/30/1899 2:12:08 AM        4
# 4                     1  12/30/1899 2:12:35 AM        5
# ...                 ...                    ...      ...
# 26405                 1  12/30/1899 7:09:39 AM    26407
# 26406                 1  12/30/1899 7:16:59 AM    26408
# 26407                 1  12/30/1899 7:19:37 AM    26409
# 26408                 1  12/30/1899 7:20:44 AM    26410
# 26409                 1  12/30/1899 7:58:14 AM    26411
#
#                          Pace State
# 0      12/30/1899 12:04:57 AM   NaN
# 1      12/30/1899 12:04:58 AM    OR
# 2      12/30/1899 12:04:59 AM   NaN
# 3      12/30/1899 12:05:03 AM    CA
# 4      12/30/1899 12:05:04 AM   NaN
# ...                       ...   ...
# 26405  12/30/1899 12:16:24 AM    CA
# 26406  12/30/1899 12:16:40 AM    NC
# 26407  12/30/1899 12:16:47 AM    PA
# 26408  12/30/1899 12:16:49 AM    NY
# 26409  12/30/1899 12:18:15 AM    GA
#
# [26410 rows x 26 columns]

# %% [markdown]
# ### In-Class Exercise #1 - Read in Boston Red Sox Hitting Data <br>
# <p>Use the pandas read_csv() method to read in the statistics from the two files yesterday.</p>

# %%
bos17 = pd.read_csv('files/redsox_2017_hitting.txt', sep=',')
bos18 = pd.read_csv('files/redsox_2018_hitting.txt', sep=',')

bos18
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B  ...    OBP  \
# 0    1   C          Sandy Leon   29   89  288  265   30   47  12  ...  0.232
# 1    2  1B      Mitch Moreland   32  124  459  404   57   99  23  ...  0.325
# 2    3  2B       Eduardo Nunez   31  127  502  480   56  127  23  ...  0.289
# 3    4  SS     Xander Bogaerts   25  136  580  513   72  148  45  ...  0.360
# 4    5  3B       Rafael Devers   21  121  490  450   59  108  24  ...  0.298
# 5    6  LF   Andrew Benintendi   23  148  661  579  103  168  41  ...  0.366
# 6    7  CF  Jackie Bradley Jr.   28  144  535  474   76  111  33  ...  0.314
# 7    8  RF        Mookie Betts   25  136  614  520  129  180  47  ...  0.438
# 8    9  DH       J.D. Martinez   30  150  649  569  111  188  37  ...  0.402
# 9   10  MI          Brock Holt   30  109  367  321   41   89  18  ...  0.362
# 10  11   C   Christian Vazquez   27   80  269  251   24   52  10  ...  0.257
# 11  12  UT       Blake Swihart   26   82  207  192   28   44  10  ...  0.285
# 12  13  UT      Hanley Ramirez   34   44  195  177   25   45   7  ...  0.313
# 13  14  1B        Steve Pearce   35   50  165  136   19   38   8  ...  0.394
# 14  15  2B         Ian Kinsler   36   37  143  132   17   32   6  ...  0.294
# 15  16  SS         Tzu-Wei Lin   24   37   73   65   15   16   6  ...  0.329
# 16  17  UT          Sam Travis   24   19   38   36    5    8   3  ...  0.263
# 17  18  UT    Brandon Phillips   37    9   27   23    4    3   0  ...  0.259
# 18  19  2B      Dustin Pedroia   34    3   13   11    1    1   0  ...  0.231
# 19  20   C          Dan Butler   31    2    7    6    0    1   0  ...  0.143
#
#       SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0   0.279  0.511    37   74    6    4   3   1    0
# 1   0.433  0.758   102  175   12    0   0   5    2
# 2   0.388  0.677    81  186   17    2   1   3    0
# 3   0.522  0.883   135  268   14    6   0   6    4
# 4   0.433  0.731    94  195    9    0   0   2    6
# 5   0.465  0.830   123  269    9    2   2   7    1
# 6   0.403  0.717    92  191    6   11   0   4    3
# 7   0.640  1.078   186  333    5    8   0   5    8
# 8   0.629  1.031   173  358   19    4   0   7   11
# 9   0.411  0.774   109  132    7    7   0   2    2
# 10  0.283  0.540    46   71    5    4   1   0    1
# 11  0.328  0.613    65   63    4    0   0   0    0
# 12  0.395  0.708    90   70    9    2   0   2    0
# 13  0.507  0.901   141   69    1    5   0   2    0
# 14  0.311  0.604    64   41    5    0   0   1    0
# 15  0.415  0.744   100   27    0    0   0   0    0
# 16  0.389  0.652    73   14    1    0   0   0    0
# 17  0.261  0.520    42    6    1    0   0   0    0
# 18  0.091  0.322    -7    1    0    0   0   0    0
# 19  0.167  0.310   -17    1    0    0   0   1    0
#
# [20 rows x 28 columns]

# %% [markdown]
# ### Accessing Data <br>

# %% [markdown]
# ##### Indexing
#
# <p>You can directly select a column of a dataframe just like you would a dict. The result is a Pandas 'Series' object.</p>

# %%
data_ages = data['ages']

print(data_ages)

print('\n')
# print out the type of the variable data
# Series
print(f'Type of single column of data: {type(data_ages)}')
# DataFrame
print(f'Type of full data table: {type(data)}')

print('\n')
# DataSeries Index - starting at 0
print(f'Fourth item in our data series @index#3: {data_ages[3]}')

print('\n')
# key first, row index second
print(f"Fourth item in ages column of our data frame: {data['ages'][3]}")

print('\n')

# we can convert our int32s from the data frame or series to other python datatypes if we want
print(float(data_ages[0]))
# Out:
# 0    24
# 1    22
# 2    33
# 3    23
# 4    25
# 5    18
# 6    29
# 7    31
# 8    34
# 9    24
# Name: ages, dtype: int32
#
#
# Type of single column of data: <class 'pandas.core.series.Series'>
# Type of full data table: <class 'pandas.core.frame.DataFrame'>
#
#
# Fourth item in our data series @index#3: 23
#
#
# Fourth item in ages column of our data frame: 23
#
#
# 24.0

# %%
print(data)

# %% [markdown]
# ##### df.loc

# %% [markdown]
# <p>Along the horizontal dimension, rows of Pandas DataFrames are Row objects. You will notice there is a third column present in the DataFrame - this is the $\textit{index}$. It is automatically generated as a row number, but can be reassigned to a column of your choice using the DataFrame.set_index(colname) method. We can use it to access particular Pandas $\textit{rows}$, which are also Series objects:</p>

# %%
# Grab the first row of data -- by the index of the row
first_row = data.loc[0]
print(type(first_row))
print(first_row)
print('\n')

# Getting Multiple values from a df.loc
multiple_rows = data.loc[[0,2,7]]
print(type(multiple_rows))
print(multiple_rows)

print('\n')
# Get names from those multiple rows
multiple_names = data.loc[[0,2,7]]['names']
print(type(multiple_names))
print(multiple_names)

print('\n')
# Using df.loc and producing a Dataframe at the end
specific_people = data.loc[[0,2,7]][['names', 'ages']]
print(type(specific_people))
print(specific_people)

print('\n')
# Reset our specific_people dataframe index based on a column
specific_people_names_index = data.loc[[0,2,7]][['names', 'ages']].set_index('names')
print(specific_people_names_index)
print(f"Accessing a row in our name-indexed dataframe:\n {specific_people_names_index.loc['Lauren']}")

print('\n')
# dataframe.reset_index()
indexes_reset = specific_people.reset_index()
print(indexes_reset)
# Out:
# <class 'pandas.core.series.Series'>
# names    Alice
# ages        24
# Name: 0, dtype: object
#
#
# <class 'pandas.core.frame.DataFrame'>
#     names  ages
# 0   Alice    24
# 2   James    33
# 7  Lauren    31
#
#
# <class 'pandas.core.series.Series'>
# 0     Alice
# 2     James
# 7    Lauren
# Name: names, dtype: object
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:416: RuntimeWarning: divide by zero encountered in subtract
#   locs = target_array - start
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in remainder
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in greater_equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in bitwise_and
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in less
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:418: RuntimeWarning: divide by zero encountered in invert
#   locs[~valid] = -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:419: RuntimeWarning: divide by zero encountered in true_divide
#   locs[valid] = locs[valid] / step
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexing.py:1357: RuntimeWarning: divide by zero encountered in less
#   missing_mask = indexer < 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:416: RuntimeWarning: divide by zero encountered in subtract
#   locs = target_array - start
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in remainder
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in greater_equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in bitwise_and
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in less
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:418: RuntimeWarning: divide by zero encountered in invert
#   locs[~valid] = -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:419: RuntimeWarning: divide by zero encountered in true_divide
#   locs[valid] = locs[valid] / step
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexing.py:1357: RuntimeWarning: divide by zero encountered in less
#   missing_mask = indexer < 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:284: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# <class 'pandas.core.frame.DataFrame'>
#     names  ages
# 0   Alice    24
# 2   James    33
# 7  Lauren    31
#
#
#         ages
# names
# Alice     24
# James     33
# Lauren    31
# Accessing a row in our name-indexed dataframe:
#  ages    31
# Name: Lauren, dtype: int32
#
#
#    index   names  ages
# 0      0   Alice    24
# 1      2   James    33
# 2      7  Lauren    31
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:416: RuntimeWarning: divide by zero encountered in subtract
#   locs = target_array - start
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in remainder
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in greater_equal
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in bitwise_and
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:417: RuntimeWarning: divide by zero encountered in less
#   valid = (locs % step == 0) & (locs >= 0) & (target_array < stop)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:418: RuntimeWarning: divide by zero encountered in invert
#   locs[~valid] = -1
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\range.py:419: RuntimeWarning: divide by zero encountered in true_divide
#   locs[valid] = locs[valid] / step
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexing.py:1357: RuntimeWarning: divide by zero encountered in less
#   missing_mask = indexer < 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:47: RuntimeWarning: divide by zero encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:534: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:284: RuntimeWarning: divide by zero encountered in less
#   mask = indices < 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in greater_equal
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in less
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexers.py:290: RuntimeWarning: divide by zero encountered in bitwise_or
#   mask = (indices >= n) | (indices < 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1196: RuntimeWarning: divide by zero encountered in invert
#   taker = (~is_deleted).nonzero()[0]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1199: RuntimeWarning: divide by zero encountered in invert
#   new_columns = self.items[~is_deleted]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: RuntimeWarning: divide by zero encountered in equal
#   return bool(asarray(a1 == a2).all())
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:358: RuntimeWarning: divide by zero encountered in invert
#   return ~res
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1323: RuntimeWarning: divide by zero encountered in bitwise_and
#   inferred
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0

# %% [markdown]
# ##### keys()

# %%
# Access all of the keys/columns of the dataframe
# Dataframe.keys()

# looking at the bos17 dataframe:
print(bos17.keys())
print(type(bos17.keys()))
print(type(bos17.keys().tolist()))
print(bos17.keys().tolist())

# %% [markdown]
# ##### Slicing a DataFrame

# %%
# same exact concept as slicing a list in python
# dataframe[starting_index : stop_before_index : step]
data[1:8:2]

# %% [markdown]
# ### Built-In Methods <br>
#
# <p>These are methods that are frequently used when using Pandas to make your life easier. It is possible to spend a whole week simply exploring the built-in functions supported by DataFrames in Pandas. Here however, we will simply highlight a few ones that might be useful, to give you an idea of what's possible out of the box with Pandas:</p>

# %% [markdown]
# ##### head()

# %%
# DataFrame.head()  -- Accepts integer parameter(gives access to more rows) default=5
bos17.head(7)

# %% [markdown]
# ##### tail()

# %%
# DataFrame.tail()  -- Accepts integer parameter(gives access to more rows)
bos17.tail()

# %% [markdown]
# ##### shape

# %%
# The dataframe has a shape property, just like a NumPy matrix. 
# print(df.shape) -- DataFrame.shape -- No Parameter
# an attribute not a method -> no parenthesis
# gives back a tuple of (rows, columns)
marathon.shape

# %% [markdown]
# ##### describe() <br>
# <p>Probably one of the most important methods to understand...</p>

# %%
# Collect summary statistics in one line
# DataFrame.describe() -- Accepts parameters (include[='all'], exclude[='none'])

# describe you can select data types to describe, not column names
bos17.describe(include='all')

# select only some columns to describe - first create a smaller dataframe with just those columns
bos17[['BA', 'HR', 'AB']].describe(percentiles=[.50, .90])

# %% [markdown]
# ##### sort_values()

# %%
# Sort based on many labels, with left-to-right priority
# sorted_data = data.sort_values('ages').reset_index()

# DataFrame.sort_values('key')

most_hrs = bos17[['Rk', 'Pos', 'Name', 'G', 'AB', 'HR', 'BA']].sort_values('HR', ascending=False).head()
most_hrs

# %% [markdown]
# ##### .columns

# %%
# will show all cols headers
# DataFrame.columns -- has no parameters

print(bos17.columns)
print(f'\n The type of bos17.columns: {type(bos17.columns)}')

print(bos17.keys())
print(f'\n The type of bos17.keys(): {type(bos17.keys())}')
# Out:
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bos17.columns: <class 'pandas.core.indexes.base.Index'>
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bos17.keys(): <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# ### In-Class Exercise #2 - Describe & Sort Boston Red Sox Hitting Data <br>
# <p>Take the data that you read in earlier from the Red Sox csv's and use the describe method to understand the data better. Compare the two years and decide which team is having the better year. Then sort the values based on Batting Average.</p>

# %%
bos17 = pd.read_csv('redsox_2017_hitting.txt', sep = ',')
bos18 = pd.read_csv('redsox_2018_hitting.txt', sep = ',')
data.keys()

print(bos17[['R','BA', 'G']].describe())
print(bos18[['R','BA', 'G']].describe())
print(sum(bos17['R']))
print(sum(bos18['R']))

#print('\n')

#print(bos17.columns)
#print('\n')

#print(type(bos17.keys().tolist()))
#print('\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-f760a9fb0557> in <module>
# ----> 1 bos17 = pd.read_csv('redsox_2017_hitting.txt', sep = ',')
#       2 bos18 = pd.read_csv('redsox_2018_hitting.txt', sep = ',')
#       3 data.keys()
#       4
#       5 print(bos17[['R','BA', 'G']].describe())
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'redsox_2017_hitting.txt'

# %% [markdown]
# ### Filtration <br>
# <p>Let's look at how to filter dataframes for rows that fulfill a specific conditon.</p>

# %% [markdown]
# ##### Conditionals

# %%
# Conditional boolean dataframe
bos['BA'] > .3

# %% [markdown]
# ##### Subsetting

# %%
# exactly like numpy
bos18[bos18['BA'] >= .3]

# %%
bestBA17 = bos17(bos17['AB'] >= 100][['Rk, 'Pos', 'Name', 'G', 'AB', 'BA']].sort_values
print(bestBA17)
bestBA18 = bos18(bos18['AB'] >= 100][['Rk, 'Pos', 'Name', 'G', 'AB', 'BA']].sort_values
print(bestBA18)
# Out:
#   File "<ipython-input-24-a6f1f4c3ca93>", line 1
#     bestBA17 = bos17(bos17['AB'] >= 100][['Rk, 'Pos', 'Name', 'G', 'AB', 'BA']].sort_values
#                                        ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %% [markdown]
# ### Column Transformations <br>
# <p>Rarely, if ever, will the columns in the original raw dataframe read from CSV or database table be the ones you actually need for your analysis. You will spend lots of time constantly transforming columns or groups of columns using general computational operations to produce new ones that are functions of the old ones. Pandas has full support for this: Consider the following dataframe containing membership term and renewal number for a group of customers:</p>

# %%
# Generate some fake data
customer_id = np.random.randint(1000,1100, 10)
renewal_nbr = np.random.randint(0,10,10)
customer_dict = {1: 0.5, 0: 1}
terms_in_years = [customer_dict[key] for key in np.random.randint(0,2,10)]

random_data = {
    'customer_id': customer_id,
    'renewal_nbr': renewal_nbr,
    'term_in_years': terms_in_years
}

customers = pd.DataFrame.from_dict(random_data)
customers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e478205aa68> in <module>
#       1 # Generate some fake data
# ----> 2 customer_id = np.random.randint(1000,1100, 10)
#       3 renewal_nbr = np.random.randint(0,10,10)
#       4 customer_dict = {1: 0.5, 0: 1}
#       5 terms_in_years = [customer_dict[key] for key in np.random.randint(0,2,10)]
#
# NameError: name 'np' is not defined

# %% [markdown]
# ##### Generating a New Column w/Data

# %%
# DataFrame['key'] = Some Calculation from our DataFrame Columns
customers['customer_tenure'] = customer['renewal_nbr']*customers['term_in_years']
customers

# drop that column
del customers['customer_tenure']
customers

# create a new column for customer ages
customers['age'] = np.random.randint(18,80,10)
customers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fe0070a085a> in <module>
#       1 # DataFrame['key'] = Some Calculation from our DataFrame Columns
# ----> 2 customers['customer_tenure'] = customer['renewal_nbr']*customers['term_in_years']
#       3 customers
#
# NameError: name 'customer' is not defined

# %% [markdown]
# ##### User Defined Function
#
# <p>If what you want to do to a column that can't be represented by simple mathematical operations, you can write your own $\textit{user defined function}$ with the full customizability available in Python and any external Python packages, then map it directly onto a column. Let's add some ages to our customer dataframe, and then classify them into our custom defined grouping scheme:</p>

# %%
# create a new column that describes the customers' age group
# so i know if I should give them a student or senior discount

# define my own function, just a python function
def age_groups(age):
    if age<18:
        return 'Child'
    elif age<=24:
        return 'Student'
    elif age<65:
        return 'Adult'
    else:
        return 'Senior'

# use .apply to map over dataframe
customers['age_group'] = customers['age'].apply(age_groups)
customers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eabc4f287105> in <module>
#      14
#      15 # use .apply to map over dataframe
# ---> 16 customers['age_group'] = customers['age'].apply(age_groups)
#      17 customers
#      18
#
# NameError: name 'customers' is not defined

# %% [markdown]
# <p>As a last example I'll show here how you would use a lambda function to create a UDF that depends on $\textit{more than one}$ column:</p>
#
# <li>UDF = User Defined Function</li>

# %%
#Axis for apply can only be 1 or 0 -- 1 being the X axis 0 being the Y axis
def get_loyalty_status(row):
    age_group = row['age_group']
    tenure = row['renewal_nbr'] * row['term_in_years']
    
    if age_group == 'Senior':
        if tenure>= 1:
            return 'loyal'
    
    elif age_group == 'Adult':
        if tenure >=2:
            return 'loyalty benefits'
        
    return 'no loyalty benefits'

customers['loyalty_status'] = customers.apply(get_loyalty_status, axis=1)
customers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-68adbd8f7590> in <module>
#      14     return 'no loyalty benefits'
#      15
# ---> 16 customers['loyalty_status'] = customers.apply(get_loyalty_status, axis=1)
#      17 customers
#
# NameError: name 'customers' is not defined

# %%
customers['customer_id'] = customers.apply(lambda)

# %% [markdown]
# ### In-Class Exercise #3 - Create Your Own UDF <br>
# <p>Using the Boston Red Sox data, create your own UDF which creates a new column called 'All-Star' and puts every player with either a batting average over .280 or an on base percentage of over .360 with a result of 'Yes' in the column and 'No' if not.</p>

# %%
"""
    Name  BA OBP AllStar
    --------------------
    Name .233 .360 Yes
    Name .150 .288 No
"""

# %% [markdown]
# ### Aggregations <br>
# <p>The raw data plus some transformations is generally only half the story. Your objective is to extract actual insights and actionable conclusions from the data, and that means reducing it from potentially billions of rows to some summary statistics via aggregation functions.</p>

# %% [markdown]
# ##### groupby() <br>
# <p>The .groupby() function is in some ways a 'master' aggregation.</p>
#
# <p>Data tables will usually reserve one column as a primary key - that is, a column for which each row has a unique value. This is to facilitate access to the exact rows of a data table that a user wants to view. The other columns will often have repeated values, such as the age groups in the above examples. We can use these columns to explore the data using the Pandas API:</p>

# %%
# also introducing .count() here, exact same as to how it's used in SQL

# Using the groupby with the column intact as a column/key
# customers.groupby('age_group', as_index = False).count()[['customer_id','age_group']]

# %% [markdown]
# ##### Type of groupby()
#
# <p>The result is a new dataframe, the columns of which all contain the counts of the grouped field. Notice the type of a grouped dataframe:</p>

# %%
print(type(customers), 'Regular Data Frame')
print(f'\n Type of Group By for Customer.GroupBy: {type(customers.groupby("age_group"))}')

# %% [markdown]
# <p>This is because simply grouping data doesn't quite make sense without an aggregation function like count() to pair with. In this case, we're counting occurances of the grouped field, but that's not all we can do. We can take averages, standard deviations, mins, maxes and much more! Let's see how this works a bit more:</p>

# %% [markdown]
# ##### mean()

# %%
# mean = average

# %% [markdown]
# ##### groupby() w/Multiple Columns
#
# <p>We end up with the average age of the groups in the last column, the average tenure in the tenure column, and so on and so forth. You can even split the groups more finely by passing a list of columns to group by:</p>

# %% [markdown]
# ##### drop_duplicates()
#
# <p>Drops all duplicates from the current dataframe</p>

# %%
customers

# %%
# Send customer data into a CSV file
customers_copy.to_csv('/files/customers.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-4c45022d6aa4> in <module>
#       1 # Send customer data into a CSV file
# ----> 2 customers_copy.to_csv('/files/customers.csv')
#
# NameError: name 'customers_copy' is not defined

# %% [markdown]
# <p>Thus the groupby operation allows you to rapidly make summary observations about the state of your entire dataset at flexible granularity. In one line above, we actually did something very complicated - that's the power of the dataframe. In fact, the process often consists of several iterative groupby operations, each revealing greater insight than the last - if you don't know where to start with a dataset, try a bunch of groupbys!</p>

# %% [markdown]
# ### Homework Excersise #1 - Find the Total Number of Runs and RBIs for the Red Sox <br>
# <p>Get total number of home runs and rbi's</p>

# %%
# step 1: Add a new column with the key 'Team' and all column values should be 'BOS'

# step 2: Group by the 'Team' column and get total home runs and rbi's

# Produce data for both 2017 and 2018 (ie print both seperated by a newline character \n)

"""
TEAM    HR   RBI
----------------
BOS     144  538
"""

# %%
bos17[bos17['AB'] >=50].sum()[['R', 'RBI']]
print(bos17[bos17['AB'] >=50].sum()[['R', 'RBI']])
print('\n')
bos18[bos18['AB'] >=50].sum()[['R', 'RBI']]
print(bos18[bos18['AB'] >=50].sum()[['R', 'RBI']])
# Out:
# R      775
# RBI    733
# dtype: object
#
#
# R      862
# RBI    816
# dtype: object

# %% [markdown]
# ## Find the average age of runners in the 2017 Boston Marathon

# %%
marathon.groupby(['Age']).mean()
# Out:
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6015: RuntimeWarning: divide by zero encountered in equal
#   mask = indexer == -1
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:795: RuntimeWarning: divide by zero encountered in int_scalars
#   max_len = max(len(mgr_locs), taker.max() + 1)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:679: RuntimeWarning: divide by zero encountered in isnan
#   checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:39: RuntimeWarning: divide by zero encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:127: RuntimeWarning: divide by zero encountered in long_scalars
#   np.array([self.adj.len(x) for x in idx]).max() + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:126: RuntimeWarning: divide by zero encountered in long_scalars
#   lwidth -= (  # type: ignore[assignment,arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:204: RuntimeWarning: divide by zero encountered in long_scalars
#   w_adjoined = w + adjoin_width
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:205: RuntimeWarning: divide by zero encountered in long_scalars
#   curr_width += w_adjoined
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:209: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 2 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\string.py:207: RuntimeWarning: divide by zero encountered in long_scalars
#   wrap = curr_width + 1 > line_width and i > 0
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\managers.py:238: RuntimeWarning: divide by zero encountered in equal
#   if (new_blknos == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:56: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:679: RuntimeWarning: divide by zero encountered in isnan
#   checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]
# C:\Users\todds\anaconda3\lib\site-packages\numpy\core\_methods.py:62: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\internals\concat.py:339: RuntimeWarning: divide by zero encountered in equal
#   if (indexer == -1).any():
# C:\Users\todds\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:254: RuntimeWarning: divide by zero encountered in isnan
#   result = np.isnan(values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1498: RuntimeWarning: divide by zero encountered in absolute
#   abs_vals = np.abs(self.values)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1502: RuntimeWarning: divide by zero encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in less
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in greater
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
# C:\Users\todds\anaconda3\lib\site-packages\pandas\io\formats\format.py:1504: RuntimeWarning: divide by zero encountered in bitwise_and
#   (abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)
#               Bib  Overall Time in Seconds  Male Average Times  \
# Age
# 18   22886.700000             15486.000000        13283.333333
# 19   17241.046512             15230.813953        14627.652174
# 20   14830.674699             14253.891566        12760.930233
# 21   13459.465753             13783.795918        12766.102941
# 22   16215.952381             14196.833333        12630.232558
# ..            ...                      ...                 ...
# 79   23856.000000             16774.333333        16774.333333
# 80   23810.000000             16410.333333        16410.333333
# 81   25116.500000             18240.000000        18240.000000
# 83   25134.000000             17079.000000        17079.000000
# 84   25269.000000             21847.000000                 NaN
#
#      Females Average Times     Division        Gender  Number of Records  \
# Age
# 18            17288.181818  3959.850000   8218.200000                1.0
# 19            15924.450000  3334.162791   7373.790698                1.0
# 20            15858.825000  3052.409639   6261.012048                1.0
# 21            14659.784810  2743.000000   5514.632653                1.0
# 22            15283.346774  2999.133333   5991.619048                1.0
# ..                     ...          ...           ...                ...
# 79                     NaN    10.666667  11487.000000                1.0
# 80                     NaN     2.666667  12069.333333                1.0
# 81                     NaN     4.500000  13251.500000                1.0
# 83                     NaN     4.000000  12748.000000                1.0
# 84            21847.000000     1.000000  11942.000000                1.0
#
#           Overall
# Age
# 18   16506.750000
# 19   14944.209302
# 20   12811.253012
# 21   11684.979592
# 22   12947.561905
# ..            ...
# 79   19659.000000
# 80   21086.000000
# 81   23728.000000
# 83   22621.000000
# 84   26342.000000
#
# [66 rows x 8 columns]
